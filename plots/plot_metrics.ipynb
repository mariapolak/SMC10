# %%
import matplotlib.pyplot as plt
import pandas as pd 
import glob 

plt.rcParams['image.cmap'] = 'Pastel1'
plt.rcParams.update({'font.size': 18, 'axes.titlesize': 22, 'axes.labelsize': 20, 'xtick.labelsize': 16, 'ytick.labelsize': 16, 'legend.fontsize': 16})

# %%
def get_ps_tsm_dataframes_csv(file_pattern: str) -> tuple[pd.DataFrame, pd.DataFrame]:
    """
    Get the dataframes for the PS and TSM data from the files that match the pattern.
    """
    df = pd.DataFrame({}) 
    for file in glob.iglob(file_pattern):
        df_tmp = pd.read_csv(file)
        df = pd.concat([df, df_tmp], ignore_index=True)

    df_ps, df_tsm = split_dataframe(df)
    
    return df_ps, df_tsm

def split_dataframe(df: pd.DataFrame) -> tuple[pd.DataFrame, pd.DataFrame]:
    df_ps = df[df['type'] == 'ps'].reset_index(drop=True)
    df_tsm = df[df['type'] == 'tsm'].reset_index(drop=True)
    
    return df_ps, df_tsm

def get_dataframe_csv(file_pattern:str) -> pd.DataFrame:
    df = pd.DataFrame({}) 
    for file in glob.iglob(file_pattern):
        df_tmp = pd.read_csv(file)
        df = pd.concat([df, df_tmp], ignore_index=True)
        
    return df

def get_dataframe_csv_no_header(file_pattern:str) -> pd.DataFrame:
    df = pd.DataFrame({}) 
    for file in glob.iglob(file_pattern):
        df_tmp = pd.read_csv(file, header=None)
        df = pd.concat([df, df_tmp], ignore_index=True)
        
    return df

# %% [markdown]
# ### STOI

# %%
df_stoi_ps, df_stoi_tsm = get_ps_tsm_dataframes_csv("evaluation/objective/stoi/*.csv")

fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
# Boxplot for df_ps
df_stoi_ps.boxplot(by='algo', column='pred_distance', rot=45, ax=axes[0])
axes[0].set_title('PS Algorithms')
axes[0].set_xlabel('Algorithm')
axes[0].set_ylabel('Predicted Distance')
axes[0].set_ylim(0, 1.1)

# Boxplot for df_tsm
df_stoi_tsm.boxplot(by='algo', column='pred_distance', rot=45, ax=axes[1])
axes[1].set_title('TSM Algorithms')
axes[1].set_xlabel('Algorithm')
# axes[1].set_ylabel('Predicted Distance')
axes[1].set_ylim(0, 1.1)

# Set the main title
fig.suptitle("STOI Results")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### SISNR

# %%
df_sisnr_ps, df_sisnr_tsm = get_ps_tsm_dataframes_csv("evaluation/objective/sisnr/*.csv")

def plot_sisnr_results(df_ps: pd.DataFrame, df_tsm: pd.DataFrame, groupby = 'algo') -> None:
    """
    Plot the SISNR results for PS and TSM algorithms.
    """
    fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

    # Boxplot for df_ps
    df_ps.boxplot(by=groupby, column='sisnr_score', rot=45, ax=axes[0])
    axes[0].set_title('PS Algorithms')
    axes[0].set_xlabel('Algorithm')
    axes[0].set_ylabel('SISNR Score')

    # Boxplot for df_tsm
    df_tsm.boxplot(by=groupby, column='sisnr_score', rot=45, ax=axes[1])
    axes[1].set_title('TSM Algorithms')
    axes[1].set_xlabel('Algorithm')

    # Set the same y-axis range for both plots
    y_min = min(df_ps['sisnr_score'].min(), df_tsm['sisnr_score'].min())
    y_max = max(df_ps['sisnr_score'].max(), df_tsm['sisnr_score'].max())
    axes[0].set_ylim(y_min * 1.05, y_max * 1.05)
    axes[1].set_ylim(y_min * 1.05, y_max * 1.05)

    # Set the main title
    fig.suptitle("SI-SNR Results")

    plt.tight_layout()
    plt.show()

plot_sisnr_results(df_sisnr_ps, df_sisnr_tsm)
plot_sisnr_results(df_sisnr_ps, df_sisnr_tsm, groupby=["algo", "factor"])

# %% [markdown]
# ### PESQ

# %%
df_pesq_ps, df_pesq_tsm = get_ps_tsm_dataframes_csv("evaluation/objective/pesq/*.csv")

fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Boxplot for df_ps
df_pesq_ps.boxplot(by='algo', column='pesq_score', rot=45, ax=axes[0])
axes[0].set_title('PS Algorithms')
axes[0].set_xlabel('Algorithm')
axes[0].set_ylabel('PESQ Score')
axes[0].set_ylim(0, 5.1)

# Boxplot for df_tsm
df_pesq_tsm.boxplot(by='algo', column='pesq_score', rot=45, ax=axes[1])
axes[1].set_title('TSM Algorithms')
axes[1].set_xlabel('Algorithm')
axes[1].set_ylim(0, 5.1)

# Set the main title
fig.suptitle("PESQ Results")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### NISQA

# %%
df_nisqa_tts = get_dataframe_csv("evaluation/objective/nisqa/tts/*.csv")

# "path" in the csv is of format "data/output/wav48/tsm/HPS/0.5/p225/p225_358.wav" where tsm, hps and 0.5 are type, algo and factor respectively
df_nisqa_tts['type'] = df_nisqa_tts['path'].apply(lambda x: x.split('/')[3])
df_nisqa_tts['algo'] = df_nisqa_tts['path'].apply(lambda x: x.split('/')[4])
df_nisqa_tts['factor'] = df_nisqa_tts['path'].apply(lambda x: x.split('/')[5])

df_nisqa_tts_ps, df_nisqa_tts_tsm = split_dataframe(df_nisqa_tts)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# Boxplot for df_ps
df_nisqa_tts_ps.boxplot(by='algo', column='mos_pred', rot=45, ax=axes[0])
axes[0].set_title('PS Algorithms')
axes[0].set_xlabel('Algorithm')
axes[0].set_ylabel('MOS Score')
axes[0].set_ylim(0, 5.1)

# Boxplot for df_tsm
df_nisqa_tts_tsm.boxplot(by='algo', column='mos_pred', rot=45, ax=axes[1])
axes[1].set_title('TSM Algorithms')
axes[1].set_xlabel('Algorithm')
axes[1].set_ylim(0, 5.1)

# Set the main title
fig.suptitle("NISQA TTS Results")

plt.tight_layout()
plt.show()

# %%
df_nisqa_tts_ps

fig, axes = plt.subplots(1, 4, figsize=(12, 6), sharey=True)

# Boxplot for df_ps
for i, algo in enumerate(df_nisqa_tts_ps['algo'].unique()):
    df_tmp = df_nisqa_tts_ps[df_nisqa_tts_ps['algo'] == algo].boxplot(column='mos_pred', by='factor', rot=45, ax=axes[i])
    axes[i].set_title(algo)
    axes[i].set_xlabel('Algorithm')
    axes[0].set_ylabel('MOS Score')
    axes[i].set_ylim(0, 5.1)
# Set the main title
fig.suptitle("NISQA TTS Results")

plt.tight_layout()
plt.show()

# %%
df_nisqa_std = get_dataframe_csv("evaluation/objective/nisqa/std/*.csv")

# "path" in the csv is of format "data/output/wav48/tsm/HPS/0.5/p225/p225_358.wav" where tsm, hps and 0.5 are type, algo and factor respectively
df_nisqa_std['type'] = df_nisqa_std['path'].apply(lambda x: x.split('/')[3])
df_nisqa_std['algo'] = df_nisqa_std['path'].apply(lambda x: x.split('/')[4])
df_nisqa_std['factor'] = df_nisqa_std['path'].apply(lambda x: x.split('/')[5])

df_nisqa_std_ps, df_nisqa_std_tsm = split_dataframe(df_nisqa_std)

# %%
fig, axes = plt.subplots(2, 5, figsize=(20, 12), sharey=True)

# Boxplots for df_ps
df_nisqa_std_ps.boxplot(by='algo', column=['mos_pred', 'noi_pred', 'dis_pred', 'col_pred', 'loud_pred'], rot=45, ax=axes[0])
for ax, metric in zip(axes[0], ['MOS', 'Noise', 'Distortion', 'Coloration', 'Loudness']):
    ax.set_title(f'PS - {metric}')
    ax.set_xlabel('Algorithm')
    axes[0][0].set_ylabel('Score')
    ax.set_ylim(0., 5.1)

# Boxplots for df_tsm
df_nisqa_std_tsm.boxplot(by='algo', column=['mos_pred', 'noi_pred', 'dis_pred', 'col_pred', 'loud_pred'], rot=45, ax=axes[1])
for ax, metric in zip(axes[1], ['MOS', 'Noise', 'Distortion', 'Coloration', 'Loudness']):
    ax.set_title(f'TSM - {metric}')
    ax.set_xlabel('Algorithm')
    axes[1][0].set_ylabel('Score')
    ax.set_ylim(0., 5.1)

# Set the main title
fig.suptitle("NISQA Results")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/9b/646lmqp56b53pz1fqqr9x5gw0000gn/T/ipykernel_52094/2375253137.py:4: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   df_nisqa_std_ps.boxplot(by='algo', column=['mos_pred', 'noi_pred', 'dis_pred', 'col_pred', 'loud_pred'], rot=45, ax=axes[0])
# /var/folders/9b/646lmqp56b53pz1fqqr9x5gw0000gn/T/ipykernel_52094/2375253137.py:12: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   df_nisqa_std_tsm.boxplot(by='algo', column=['mos_pred', 'noi_pred', 'dis_pred', 'col_pred', 'loud_pred'], rot=45, ax=axes[1])

# %% [markdown]
# ### Audio Aesthetics

# %%
df_aa = pd.DataFrame({}) 
for file in glob.iglob("evaluation/objective/audio_aesthetics/*.jsonl"):
    df_tmp = pd.read_json(file, lines=True)
    df_aa = pd.concat([df_aa, df_tmp], ignore_index=True)
    
df_aa['type'] = df_aa['path'].apply(lambda x: x.split('/')[3])
df_aa['algo'] = df_aa['path'].apply(lambda x: x.split('/')[4])
df_aa['factor'] = df_aa['path'].apply(lambda x: x.split('/')[5])

df_aa_ps, df_aa_tsm = split_dataframe(df_aa)
df_aa_ps
# Out:
#                                                    path        CE        CU  \
# 0      data/output/wav48/ps/PSOLA/-12/p225/p225_315.wav  4.520402  4.990805
# 1      data/output/wav48/ps/PSOLA/-12/p225/p225_293.wav  4.690906  5.610269
# 2      data/output/wav48/ps/PSOLA/-12/p225/p225_018.wav  4.638297  6.122905
# 3      data/output/wav48/ps/PSOLA/-12/p225/p225_071.wav  3.969161  4.253335
# 4      data/output/wav48/ps/PSOLA/-12/p225/p225_324.wav  4.725746  5.894459
# ...                                                 ...       ...       ...
# 25411    data/output/wav48/ps/NMPS/12/p230/p230_366.wav  3.393949  3.538830
# 25412    data/output/wav48/ps/NMPS/12/p230/p230_263.wav  3.100162  3.420024
# 25413    data/output/wav48/ps/NMPS/12/p230/p230_139.wav  3.669910  3.311143
# 25414    data/output/wav48/ps/NMPS/12/p230/p230_027.wav  3.978874  4.165173
# 25415    data/output/wav48/ps/NMPS/12/p230/p230_401.wav  3.962102  4.200127
#
#              PC        PQ type   algo factor
# 0      1.636981  4.844841   ps  PSOLA    -12
# 1      1.590294  5.729999   ps  PSOLA    -12
# 2      1.661611  5.815604   ps  PSOLA    -12
# 3      1.857656  4.115571   ps  PSOLA    -12
# 4      1.696331  5.264143   ps  PSOLA    -12
# ...         ...       ...  ...    ...    ...
# 25411  2.616796  3.354205   ps   NMPS     12
# 25412  2.108327  3.172551   ps   NMPS     12
# 25413  2.312520  3.929415   ps   NMPS     12
# 25414  1.954257  4.645830   ps   NMPS     12
# 25415  2.164772  5.068302   ps   NMPS     12
#
# [25416 rows x 8 columns]

# %%
# Calculate global y-axis limits for each metric
metrics = ['CE', 'CU', 'PC', 'PQ']
y_lims = {
    metric: (
        min(df_aa_ps[metric].min(), df_aa_tsm[metric].min()) * 0.9,
        max(df_aa_ps[metric].max(), df_aa_tsm[metric].max()) * 1.1
    )
    for metric in metrics
}

fig, axes = plt.subplots(2, 4, figsize=(20, 12), sharey=True)

# Boxplots for df_ps
df_aa_ps.boxplot(by='algo', column=metrics, rot=45, ax=axes[0])
for ax, metric in zip(axes[0], metrics):
    ax.set_title(f'PS - {metric}')
    ax.set_xlabel('Algorithm')
    axes[0][0].set_ylabel('Score')
    ax.set_ylim(0, 10)

# Boxplots for df_tsm
df_aa_tsm.boxplot(by='algo', column=metrics, rot=45, ax=axes[1])
for ax, metric in zip(axes[1], metrics):
    ax.set_title(f'TSM - {metric}')
    ax.set_xlabel('Algorithm')
    axes[1][0].set_ylabel('Score')

# Set the main title
fig.suptitle("Audio Aesthetics Results")

plt.tight_layout()
plt.show()
# Out:
# /var/folders/9b/646lmqp56b53pz1fqqr9x5gw0000gn/T/ipykernel_52094/2035129622.py:14: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   df_aa_ps.boxplot(by='algo', column=metrics, rot=45, ax=axes[0])
# /var/folders/9b/646lmqp56b53pz1fqqr9x5gw0000gn/T/ipykernel_52094/2035129622.py:22: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   df_aa_tsm.boxplot(by='algo', column=metrics, rot=45, ax=axes[1])

# %% [markdown]
# ### VISQOL

# %%
df_visqol = get_dataframe_csv_no_header("evaluation/objective/visqol/*.csv")
df_visqol.columns = ['input_path', 'output_path', 'score']

df_visqol['type'] = df_visqol['output_path'].apply(lambda x: x.split('/')[4])
df_visqol['algo'] = df_visqol['output_path'].apply(lambda x: x.split('/')[5])
df_visqol['factor'] = df_visqol['output_path'].apply(lambda x: x.split('/')[6])

df_visqol_ps, df_visqol_tsm = split_dataframe(df_visqol)
df_visqol_ps
# Out:
#                                 input_path  \
# 0      /data/input/wav16/p225/p225_315.wav
# 1      /data/input/wav16/p225/p225_293.wav
# 2      /data/input/wav16/p225/p225_018.wav
# 3      /data/input/wav16/p225/p225_071.wav
# 4      /data/input/wav16/p225/p225_324.wav
# ...                                    ...
# 16939  /data/input/wav16/p230/p230_366.wav
# 16940  /data/input/wav16/p230/p230_263.wav
# 16941  /data/input/wav16/p230/p230_139.wav
# 16942  /data/input/wav16/p230/p230_027.wav
# 16943  /data/input/wav16/p230/p230_401.wav
#
#                                              output_path     score type  \
# 0      /data/output/wav16/ps/NMPS/rt_down/p225/p225_3...  2.440720   ps
# 1      /data/output/wav16/ps/NMPS/rt_down/p225/p225_2...  2.436506   ps
# 2      /data/output/wav16/ps/NMPS/rt_down/p225/p225_0...  2.435463   ps
# 3      /data/output/wav16/ps/NMPS/rt_down/p225/p225_0...  2.437389   ps
# 4      /data/output/wav16/ps/NMPS/rt_down/p225/p225_3...  2.436035   ps
# ...                                                  ...       ...  ...
# 16939  /data/output/wav16/ps/LibrosaPS/rt_down/p230/p...  2.487868   ps
# 16940  /data/output/wav16/ps/LibrosaPS/rt_down/p230/p...  2.503077   ps
# 16941  /data/output/wav16/ps/LibrosaPS/rt_down/p230/p...  2.508588   ps
# 16942  /data/output/wav16/ps/LibrosaPS/rt_down/p230/p...  2.600742   ps
# 16943  /data/output/wav16/ps/LibrosaPS/rt_down/p230/p...  2.447801   ps
#
#             algo   factor
# 0           NMPS  rt_down
# 1           NMPS  rt_down
# 2           NMPS  rt_down
# 3           NMPS  rt_down
# 4           NMPS  rt_down
# ...          ...      ...
# 16939  LibrosaPS  rt_down
# 16940  LibrosaPS  rt_down
# 16941  LibrosaPS  rt_down
# 16942  LibrosaPS  rt_down
# 16943  LibrosaPS  rt_down
#
# [16944 rows x 6 columns]

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Boxplot for df_ps
df_visqol_ps.boxplot(by='algo', column='score', rot=45, ax=axes[0])
axes[0].set_title('PS Algorithms')
axes[0].set_xlabel('Algorithm')
axes[0].set_ylabel('VISQOL Score')
axes[0].set_ylim(0., 5.1)

# Boxplot for df_tsm
df_visqol_tsm.boxplot(by='algo', column='score', rot=45, ax=axes[1])
axes[1].set_title('TSM Algorithms')
axes[1].set_xlabel('Algorithm')
axes[1].set_ylabel('VISQOL Score')
axes[1].set_ylim(0., 5.1)

# Set the main title
fig.suptitle("VISQOL Results")

plt.tight_layout()
plt.show()

# %%
#define dataframe for averages and std for each metric

df_avg_std = pd.DataFrame()
algo = df_stoi_ps['algo'].unique()

for algo in algo:
    stoi_avg = df_stoi_ps[df_stoi_ps['algo'] == algo]['pred_distance'].mean()
    stoi_std = df_stoi_ps[df_stoi_ps['algo'] == algo]['pred_distance'].std()
    pesq_avg = df_pesq_ps[df_pesq_ps['algo'] == algo]['pesq_score'].mean()
    pesq_std = df_pesq_ps[df_pesq_ps['algo'] == algo]['pesq_score'].std()
    
    visqol_avg = df_visqol_ps[df_visqol_ps['algo'] == algo]['score'].mean()
    visqol_std = df_visqol_ps[df_visqol_ps['algo'] == algo]['score'].std()
    
    sisnr_avg = df_sisnr_ps[df_sisnr_ps['algo'] == algo]['sisnr_score'].mean()
    sisnr_std = df_sisnr_ps[df_sisnr_ps['algo'] == algo]['sisnr_score'].std()
    
    nisqa_tts_avg = df_nisqa_tts_ps[df_nisqa_tts_ps['algo'] == algo]['mos_pred'].mean()
    nisqa_tts_std = df_nisqa_tts_ps[df_nisqa_tts_ps['algo'] == algo]['mos_pred'].std()
    
    nisqa_mos_avg = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['mos_pred'].mean()
    nisqa_mos_std = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['mos_pred'].std()
    niqsa_noise_avg = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['noi_pred'].mean()
    nisqa_noise_std = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['noi_pred'].std()
    nisqa_distortion_avg = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['dis_pred'].mean()
    nisqa_distortion_std = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['dis_pred'].std()
    nisqa_col_avg = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['col_pred'].mean()
    nisqa_col_std = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['col_pred'].std()
    nisqa_loud_avg = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['loud_pred'].mean()
    nisqa_loud_std = df_nisqa_std_ps[df_nisqa_std_ps['algo'] == algo]['loud_pred'].std()
    aa_ce_avg = df_aa_ps[df_aa_ps['algo'] == algo]['CE'].mean()
    aa_ce_std = df_aa_ps[df_aa_ps['algo'] == algo]['CE'].std()
    aa_cu_avg = df_aa_ps[df_aa_ps['algo'] == algo]['CU'].mean()
    aa_cu_std = df_aa_ps[df_aa_ps['algo'] == algo]['CU'].std()
    aa_pc_avg = df_aa_ps[df_aa_ps['algo'] == algo]['PC'].mean()
    aa_pc_std = df_aa_ps[df_aa_ps['algo'] == algo]['PC'].std()
    aa_pq_avg = df_aa_ps[df_aa_ps['algo'] == algo]['PQ'].mean()
    aa_pq_std = df_aa_ps[df_aa_ps['algo'] == algo]['PQ'].std()
    
    # append to dataframe
    df_avg_std = pd.concat([df_avg_std, pd.DataFrame({
        'algo': [algo],
        'STOI': [stoi_avg],
        'STOI STD': [stoi_std],
        'PESQ': [pesq_avg],
        'PESQ STD': [pesq_std],
        'VISQOL': [visqol_avg],
        'VISQOL STD': [visqol_std],
        'SISNR': [sisnr_avg],
        'SISNR STD': [sisnr_std],
        'NISQA TTS': [nisqa_tts_avg],
        'NISQA TTS STD': [nisqa_tts_std],
        'NISQA MOS': [nisqa_mos_avg],
        'NISQA MOS STD': [nisqa_mos_std],
        'NISQA NOISE': [niqsa_noise_avg],
        'NISQA NOISE STD': [nisqa_noise_std],
        'NISQA DIST': [nisqa_distortion_avg],
        'NISQA DIST STD': [nisqa_distortion_std],
        'NISQA COL': [nisqa_col_avg],
        'NISQA COL STD': [nisqa_col_std],
        'NISQA LOUD': [nisqa_loud_avg],
        'NISQA LOUD STD': [nisqa_loud_std],
        'AA CE': [aa_ce_avg],
        'AA CE STD': [aa_ce_std],
        'AA AU': [aa_cu_avg],
        'AA AU STD': [aa_cu_std],
        'AA PC': [aa_pc_avg],
        'AA PC STD': [aa_pc_std],
        'AA PQ': [aa_pq_avg],
        'AA PQ STD': [aa_pq_std],
    })], ignore_index=True)
    

# add tsm

for algo in df_stoi_tsm['algo'].unique():
    stoi_avg = df_stoi_tsm[df_stoi_tsm['algo'] == algo]['pred_distance'].mean()
    stoi_std = df_stoi_tsm[df_stoi_tsm['algo'] == algo]['pred_distance'].std()
    pesq_avg = df_pesq_tsm[df_pesq_tsm['algo'] == algo]['pesq_score'].mean()
    pesq_std = df_pesq_tsm[df_pesq_tsm['algo'] == algo]['pesq_score'].std()
    
    visqol_avg = df_visqol_tsm[df_visqol_tsm['algo'] == algo]['score'].mean()
    visqol_std = df_visqol_tsm[df_visqol_tsm['algo'] == algo]['score'].std()
    
    sisnr_avg = df_sisnr_tsm[df_sisnr_tsm['algo'] == algo]['sisnr_score'].mean()
    sisnr_std = df_sisnr_tsm[df_sisnr_tsm['algo'] == algo]['sisnr_score'].std()
    
    nisqa_tts_avg = df_nisqa_tts_tsm[df_nisqa_tts_tsm['algo'] == algo]['mos_pred'].mean()
    nisqa_tts_std = df_nisqa_tts_tsm[df_nisqa_tts_tsm['algo'] == algo]['mos_pred'].std()
    
    nisqa_mos_avg = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['mos_pred'].mean()
    nisqa_mos_std = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['mos_pred'].std()
    niqsa_noise_avg = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['noi_pred'].mean()
    nisqa_noise_std = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['noi_pred'].std()
    nisqa_distortion_avg = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['dis_pred'].mean()
    nisqa_distortion_std = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['dis_pred'].std()
    nisqa_col_avg = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['col_pred'].mean()
    nisqa_col_std = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['col_pred'].std()
    nisqa_loud_avg = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['loud_pred'].mean()
    nisqa_loud_std = df_nisqa_std_tsm[df_nisqa_std_tsm['algo'] == algo]['loud_pred'].std()
    aa_ce_avg = df_aa_tsm[df_aa_tsm['algo'] == algo]['CE'].mean()
    aa_ce_std = df_aa_tsm[df_aa_tsm['algo'] == algo]['CE'].std()
    aa_cu_avg = df_aa_tsm[df_aa_tsm['algo'] == algo]['CU'].mean()
    aa_cu_std = df_aa_tsm[df_aa_tsm['algo'] == algo]['CU'].std()
    aa_pc_avg = df_aa_tsm[df_aa_tsm['algo'] == algo]['PC'].mean()
    aa_pc_std = df_aa_tsm[df_aa_tsm['algo'] == algo]['PC'].std()
    aa_pq_avg = df_aa_tsm[df_aa_tsm['algo'] == algo]['PQ'].mean()
    aa_pq_std = df_aa_tsm[df_aa_tsm['algo'] == algo]['PQ'].std()

    # append to dataframe
    df_avg_std = pd.concat([df_avg_std, pd.DataFrame({
        'algo': [algo],
        'STOI': [stoi_avg],
        'STOI STD': [stoi_std],
        'PESQ': [pesq_avg],
        'PESQ STD': [pesq_std],
        'VISQOL': [visqol_avg],
        'VISQOL STD': [visqol_std],
        'SISNR': [sisnr_avg],
        'SISNR STD': [sisnr_std],
        'NISQA TTS': [nisqa_tts_avg],
        'NISQA TTS STD': [nisqa_tts_std],
        'NISQA MOS': [nisqa_mos_avg],
        'NISQA MOS STD': [nisqa_mos_std],
        'NISQA NOISE': [niqsa_noise_avg],
        'NISQA NOISE STD': [nisqa_noise_std],
        'NISQA DIST': [nisqa_distortion_avg],
        'NISQA DIST STD': [nisqa_distortion_std],
        'NISQA COL': [nisqa_col_avg],
        'NISQA COL STD': [nisqa_col_std],
        'NISQA LOUD': [nisqa_loud_avg],
        'NISQA LOUD STD': [nisqa_loud_std],
        'AA CE': [aa_ce_avg],
        'AA CE STD': [aa_ce_std],
        'AA AU': [aa_cu_avg],
        'AA AU STD': [aa_cu_std],
        'AA PC': [aa_pc_avg],
        'AA PC STD': [aa_pc_std],
        'AA PQ': [aa_pq_avg],
        'AA PQ STD': [aa_pq_std],
    })], ignore_index=True)
    
df_avg_std.to_csv("evaluation/objective/metrics_avg_std.csv", index=False)
