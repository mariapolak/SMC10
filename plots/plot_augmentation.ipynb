# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
plt.rcParams.update({'font.size': 18, 'axes.titlesize': 22, 'axes.labelsize': 20, 'xtick.labelsize': 16, 'ytick.labelsize': 16, 'legend.fontsize': 16})

# %% [markdown]
# #### Data augementation distribution tests

# %%
ps_factors = []
tsm_factors = []
for i in range(100000):
    ps_factor = np.random.uniform(-3, 5)
    ps_factors.append(ps_factor)

    tsm_factor =  np.random.uniform(0.75, 1.35)
    tsm_factors.append(tsm_factor)

plt.figure(figsize=(10, 5))
plt.hist(ps_factors, bins=1000, alpha=0.5, label='Pitch_Shift_Factor')
plt.xlabel('Sample Number')
plt.ylabel('Factor Value')
plt.title('Randomly Generated Factors')
plt.show()

plt.figure(figsize=(10, 5))
plt.hist(tsm_factors, bins=1000, alpha=0.5, label='tsm_factors')
plt.xlabel('Sample Number')
plt.ylabel('Factor Value')
plt.title('Randomly Generated Factors')
plt.show()

# %% [markdown]
# ### Data Augmentation Stats:

# %%
df_res = pd.read_csv('data/output_rs/SpeechDatasets/VCTK/wav16_silence_trimmed/augmented_files.csv')
df_res = df_res[df_res['Resampling_Factor'] != 0]
df_res
# Out:
#                                                  Filename  Resampling_Factor
# 1       data/output_2504191240/SpeechDatasets/VCTK/wav...           0.623672
# 2       data/output_2504191240/SpeechDatasets/VCTK/wav...           1.401791
# 3       data/output_2504191240/SpeechDatasets/VCTK/wav...           1.045498
# 5       data/output_2504191240/SpeechDatasets/VCTK/wav...           0.623672
# 6       data/output_2504191240/SpeechDatasets/VCTK/wav...           1.401791
# ...                                                   ...                ...
# 177814  data/output_2504191240/SpeechDatasets/VCTK/wav...           1.015760
# 177815  data/output_2504191240/SpeechDatasets/VCTK/wav...           1.173386
# 177817  data/output_2504191240/SpeechDatasets/VCTK/wav...           0.584595
# 177818  data/output_2504191240/SpeechDatasets/VCTK/wav...           1.015760
# 177819  data/output_2504191240/SpeechDatasets/VCTK/wav...           1.173386
#
# [133365 rows x 2 columns]

# %%
df_pstsm = pd.read_csv('data/output_pstsm/SpeechDatasets/VCTK/wav16_silence_trimmed/augmented_files.csv')
df_pstsm = df_pstsm[(df_pstsm['Pitch_Shift_Factor'] != 0) & (df_pstsm['Time_Stretch_Factor'] != 1)]

df_pstsm
# Out:
#                                                  Filename  Pitch_Shift_Factor  \
# 1       data/output_2504181317/SpeechDatasets/VCTK/wav...            0.435111
# 2       data/output_2504181317/SpeechDatasets/VCTK/wav...           -2.293918
# 3       data/output_2504181317/SpeechDatasets/VCTK/wav...            2.366603
# 5       data/output_2504181317/SpeechDatasets/VCTK/wav...            0.435111
# 6       data/output_2504181317/SpeechDatasets/VCTK/wav...           -2.293918
# ...                                                   ...                 ...
# 177814  data/output_2504181317/SpeechDatasets/VCTK/wav...            4.906507
# 177815  data/output_2504181317/SpeechDatasets/VCTK/wav...            4.745136
# 177817  data/output_2504181317/SpeechDatasets/VCTK/wav...            0.398175
# 177818  data/output_2504181317/SpeechDatasets/VCTK/wav...            4.906507
# 177819  data/output_2504181317/SpeechDatasets/VCTK/wav...            4.745136
#
#         Time_Stretch_Factor
# 1                  0.765201
# 2                  1.323567
# 3                  1.013678
# 5                  1.114586
# 6                  1.306438
# ...                     ...
# 177814             0.827837
# 177815             0.759227
# 177817             0.832741
# 177818             1.310083
# 177819             0.773938
#
# [133365 rows x 3 columns]

# %%
# plot the distrubution of resampling_factor in df_res
plt.figure(figsize=(10, 5))
plt.hist(df_res['Resampling_Factor'], bins=50, alpha=0.5, label='Resampling Factor')
plt.xlabel('Resampling Factor')
plt.ylabel('Count')
plt.title('Distribution of Resampling Factor')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.hist(df_pstsm['Pitch_Shift_Factor'], bins=50, alpha=0.5, label='Pitch Shift Factor')
plt.xlabel('Pitch Shift Factor')
plt.ylabel('Count')
plt.title('Distribution of Pitch Shift Factor')
plt.legend()
plt.show()



plt.figure(figsize=(10, 5))
plt.hist(df_pstsm['Time_Stretch_Factor'], bins=50, alpha=0.5, label='Time Stretch Factor')
plt.xlabel('Time Stretch Factor')
plt.ylabel('Count')
plt.title('Distribution of Time Stretch Factor')
plt.legend()
plt.show()
